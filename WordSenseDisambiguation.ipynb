# %% [markdown]
# # Word Sense Disambiguation

# %%
import pandas as pd
import math
from collections import defaultdict

# %%
df=pd.read_csv('/content/Bank - Sheet1.csv')
#df.columns=df.columns.str.strip()
df.head()
# Out:
#    Unnamed: 0                            Sentences for Training   \
# 0         NaN               I deposited my paycheck at the bank.
# 1         NaN  The bank of the river was eroded by the heavy ...
# 2         NaN                She works at the bank as a teller.
# 3         NaN     Let's have a picnic by the bank of the river.
# 4         NaN            The bank approved my loan application.
#
#   Sense of the word "Bank"
# 0    Financial Institution
# 1             River Border
# 2    Financial Institution
# 3             River Border
# 4    Financial Institution

# %%
df=df.dropna(subset=['Sense of the word "Bank"'])
test_df=df[df['Sense of the word "Bank"']=='?']
df=df[df['Sense of the word "Bank"']!='?']

# %%
test_df
# Out:
#      Unnamed: 0                            Sentences for Training   \
# 94          NaN  The children built a dam on the bank of the ri...
# 95          NaN  We need to withdraw some cash from the bank fo...
# 96          NaN  I need to update my contact information with t...
# 97          NaN  The bank provides online banking services for ...
# 98          NaN  The beavers constructed a dam along the bank o...
# 99          NaN  I need to check my transaction history at the ...
# 100         NaN  She works as a financial consultant at the bank.
#
#     Sense of the word "Bank"
# 94                         ?
# 95                         ?
# 96                         ?
# 97                         ?
# 98                         ?
# 99                         ?
# 100                        ?

# %%
training_data=list(zip(df['Sentences for Training '],df['Sense of the word "Bank"']))
word_counts={
    'Financial Institution':defaultdict(int),
    'River Border':defaultdict(int)
}
sense_counts=defaultdict(int)
total_words=0

# %%
for sentence, sense in training_data:
    words = sentence.lower().split()
    sense_counts[sense] += 1
    for word in words:
        word_counts[sense][word] += 1
        total_words += 1

# %%
for sentence,sense in training_data:
  words=sentence.lower().split()
  sense_counts[sense]+=1
  for word in words:
    word_counts[sense][word]+=1
    total_words+=1
word_counts
# Out:
# {'Financial Institution': defaultdict(int,
#              {' ': 1209,
#               'I': 51,
#               'd': 180,
#               'e': 750,
#               'p': 108,
#               'o': 354,
#               's': 330,
#               'i': 408,
#               't': 549,
#               'm': 120,
#               'y': 75,
#               'a': 627,
#               'c': 249,
#               'h': 273,
#               'k': 192,
#               'b': 168,
#               'n': 510,
#               '.': 135,
#               'S': 18,
#               'w': 60,
#               'r': 324,
#               'l': 108,
#               'T': 63,
#               'v': 75,
#               'W': 9,
#               'f': 132,
#               'u': 102,
#               '9': 9,
#               '5': 9,
#               'g': 75,
#               'H': 3,
#               'A': 6,
#               'M': 6,
#               "'": 21,
#               'q': 9,
#               '(': 6,
#               'F': 6,
#               ')': 6,
#               'x': 6,
#               '-': 3,
#               'B': 0,
#               'L': 0,
#               'j': 0,
#               'D': 0,
#               ',': 0,
#               'R': 0,
#               'deposited': 6,
#               'my': 66,
#               'paycheck': 6,
#               'at': 102,
#               'the': 306,
#               'bank.': 90,
#               'she': 36,
#               'works': 30,
#               'bank': 132,
#               'as': 30,
#               'teller.': 6,
#               'approved': 6,
#               'loan': 18,
#               'application.': 6,
#               'we': 18,
#               'need': 102,
#               'to': 156,
#               'transfer': 24,
#               'funds': 12,
#               'between': 12,
#               'banks.': 6,
#               'is': 6,
#               'open': 12,
#               'from': 18,
#               'am': 6,
#               'pm.': 6,
#               'check': 36,
#               'account': 24,
#               'balance': 12,
#               'invested': 6,
#               'her': 6,
#               'savings': 24,
#               'in': 24,
#               'stock': 6,
#               'market': 6,
#               'through': 6,
#               'he': 6,
#               'withdrew': 6,
#               'cash': 6,
#               'atm': 12,
#               'offers': 36,
#               'various': 6,
#               'financial': 36,
#               'services': 12,
#               'its': 6,
#               'customers.': 6,
#               'they': 6,
#               'applied': 6,
#               'for': 36,
#               'mortgage': 12,
#               'buy': 6,
#               'house.': 6,
#               "bank's": 30,
#               'profits': 6,
#               'soared': 6,
#               'last': 6,
#               'quarter.': 6,
#               'interest': 12,
#               'rates': 18,
#               'analyst': 6,
#               'money': 12,
#               'our': 12,
#               'overseas': 6,
#               'account.': 12,
#               'manager': 6,
#               'greeted': 6,
#               'customers': 6,
#               'with': 18,
#               'warm': 6,
#               'smile.': 6,
#               '(financial': 12,
#               'institution)': 12,
#               'security': 12,
#               'system': 6,
#               'prevented': 6,
#               'robbery.': 6,
#               "hey're": 6,
#               'planning': 12,
#               'new': 12,
#               'branch': 6,
#               'of': 12,
#               'city': 6,
#               'center.': 6,
#               'offered': 6,
#               'competitive': 12,
#               'on': 6,
#               'accounts.': 6,
#               'provided': 12,
#               'construction': 6,
#               'home.': 6,
#               'visit': 12,
#               'deposit': 18,
#               'this': 18,
#               'check.': 6,
#               'headquarters': 12,
#               'are': 12,
#               'located': 12,
#               'district.': 6,
#               'update': 18,
#               'information': 12,
#               'online': 12,
#               'banking': 18,
#               'convenience.': 6,
#               'officer': 6,
#               'exchange': 6,
#               'before': 6,
#               'traveling.': 6,
#               'assistance': 6,
#               'small': 6,
#               'businesses.': 6,
#               'schedule': 6,
#               'meeting': 6,
#               'manager.': 6,
#               'credit': 12,
#               'cards': 6,
#               'attractive': 6,
#               'rewards.': 6,
#               'guard': 6,
#               'apprehended': 6,
#               'thief.': 6,
#               "sister's": 6,
#               'advisor': 6,
#               'direct': 6,
#               'deposit.': 6,
#               'investment': 6,
#               'opportunities': 6,
#               'long-term': 6,
#               'growth.': 6,
#               'into': 12,
#               'provides': 6,
#               'excellent': 6,
#               'customer': 6,
#               'service.': 6,
#               'password.': 6,
#               'corporate': 6,
#               'city.': 6,
#               'checking': 12,
#               'and': 6,
#               'accounts': 6,
#               'retirement': 6,
#               'services.': 6,
#               'planner': 6,
#               'make': 6,
#               'withdrawal': 6,
#               'apply': 6,
#               'card.': 6,
#               'rates.': 6}),
#  'River Border': defaultdict(int,
#              {'T': 135,
#               'h': 546,
#               'e': 1011,
#               ' ': 1569,
#               'b': 204,
#               'a': 582,
#               'n': 429,
#               'k': 201,
#               'o': 459,
#               'f': 204,
#               't': 543,
#               'r': 603,
#               'i': 399,
#               'v': 186,
#               'w': 90,
#               's': 360,
#               'd': 231,
#               'y': 93,
#               '.': 144,
#               'L': 3,
#               "'": 3,
#               'p': 93,
#               'c': 141,
#               'm': 90,
#               'l': 282,
#               'u': 87,
#               'D': 3,
#               'g': 138,
#               ',': 6,
#               'W': 3,
#               'j': 6,
#               '(': 9,
#               'R': 9,
#               'B': 9,
#               ')': 9,
#               'q': 3,
#               'x': 0,
#               'A': 0,
#               'M': 0,
#               'H': 0,
#               '5': 0,
#               'S': 0,
#               '-': 0,
#               'I': 0,
#               '9': 0,
#               'F': 0,
#               'the': 852,
#               'bank': 282,
#               'of': 300,
#               'river': 54,
#               'was': 36,
#               'eroded': 6,
#               'by': 42,
#               'heavy': 6,
#               'rains.': 6,
#               "let's": 6,
#               'have': 6,
#               'picnic': 12,
#               'river.': 222,
#               'fisherman': 6,
#               'cast': 12,
#               'his': 6,
#               'line': 6,
#               'near': 12,
#               'children': 36,
#               'built': 18,
#               'sandcastle': 6,
#               'ducks': 12,
#               'were': 12,
#               'swimming': 6,
#               'peacefully': 6,
#               'along': 114,
#               'campsite': 6,
#               'situated': 6,
#               'trees': 18,
#               'shaded': 6,
#               'river,': 12,
#               'creating': 6,
#               'serene': 6,
#               'atmosphere.': 6,
#               'canoeists': 12,
#               'navigated': 12,
#               'winding': 6,
#               'water': 12,
#               'level': 6,
#               'rose': 6,
#               'dangerously': 6,
#               'close': 6,
#               'to': 18,
#               'we': 6,
#               'enjoyed': 6,
#               'leisurely': 6,
#               'stroll': 6,
#               'otters': 18,
#               'frolicked': 6,
#               'kids': 12,
#               'skipped': 18,
#               'stones': 12,
#               'across': 18,
#               'calm': 12,
#               'provided': 12,
#               'natural': 12,
#               'barrier': 6,
#               'against': 6,
#               'flooding.': 6,
#               'sunset': 6,
#               'painted': 6,
#               'in': 18,
#               'vibrant': 6,
#               'hues.': 6,
#               '(river': 18,
#               'border)': 18,
#               'fishermen': 12,
#               'set': 18,
#               'up': 12,
#               'their': 12,
#               'gear': 6,
#               'hikers': 6,
#               'followed': 6,
#               'trail': 6,
#               'deer': 6,
#               'came': 6,
#               'drink': 6,
#               'from': 18,
#               'cool': 6,
#               'waters': 12,
#               'at': 6,
#               'kayakers': 6,
#               'paddled': 6,
#               'downstream': 6,
#               'meandering': 6,
#               'heron': 12,
#               'stood': 6,
#               'majestically': 6,
#               'on': 24,
#               'waiting': 6,
#               'for': 18,
#               'its': 6,
#               'prey.': 6,
#               'old': 6,
#               'oak': 6,
#               'tree': 6,
#               'marked': 6,
#               'bend': 6,
#               'slid': 6,
#               'playfully': 6,
#               'down': 6,
#               'muddy': 12,
#               'swans': 6,
#               'gracefully': 6,
#               'glided': 6,
#               'glassy': 6,
#               'rocks': 12,
#               'smooth': 12,
#               'teeming': 6,
#               'with': 6,
#               'wildlife.': 6,
#               'campers': 6,
#               'tents': 6,
#               'sound': 6,
#               'rushing': 6,
#               'echoed': 6,
#               'willow': 6,
#               'swayed': 6,
#               'gently': 6,
#               'collected': 6,
#               'pebbles': 6,
#               'blanket': 6,
#               'spread': 6,
#               'out': 6,
#               'grassy': 12,
#               'beavers': 6,
#               'dam': 6,
#               'home': 6,
#               'variety': 6,
#               'aquatic': 6,
#               'plants.': 6,
#               'caught': 6,
#               'tadpoles': 6,
#               'shallow': 6,
#               'sun': 6,
#               'behind': 6,
#               'tall': 6,
#               'lining': 6,
#               'years': 6,
#               'erosion.': 6,
#               'perched': 6,
#               'branch': 6,
#               'overlooking': 6,
#               'splashed': 6,
#               'shallows': 6,
#               'moonlight': 6,
#               'shimmered': 6,
#               'still': 6,
#               'reeds': 6,
#               'rustled': 6,
#               'softly': 6,
#               'swimmers': 6,
#               'crossed': 6,
#               'holding': 6,
#               'onto': 6,
#               'bank.': 6,
#               'waddled': 6,
#               'habitat': 6,
#               'frogs': 6,
#               'and': 6,
#               'turtles.': 6,
#               'rowers': 6,
#               'raced': 6,
#               'straight': 6,
#               'lines': 6,
#               'rocky': 6,
#               'through': 6,
#               'narrow': 6,
#               'sandcastles': 6,
#               'sandy': 6,
#               'played': 6,
#               'popular': 6,
#               'spot': 6,
#               'picnics.': 6})}

# %%
total_sentences=len(training_data)
prior_probabilities={
    sense:count/total_sentences for sense,count in sense_counts.items()
}
prior_probabilities
# Out:
# {'Financial Institution': 4.354838709677419, 'River Border': 4.645161290322581}

# %%
vocabulary=set(word for sense in word_counts for word in word_counts[sense])
vocab_size=len(vocabulary)

conditional_probabilities={
    sense:{word:(word_counts[sense][word]+1)/(sum(word_counts[sense].values())+vocab_size) for word in vocabulary} for sense in word_counts
}
conditional_probabilities
# Out:
# {'Financial Institution': {'W': 0.000994233446013124,
#   'painted': 9.942334460131238e-05,
#   'p': 0.01083714456154305,
#   '(river': 9.942334460131238e-05,
#   'erosion.': 9.942334460131238e-05,
#   'password.': 0.0006959634122091867,
#   'flooding.': 9.942334460131238e-05,
#   'drink': 9.942334460131238e-05,
#   'cards': 0.0006959634122091867,
#   'navigated': 9.942334460131238e-05,
#   'raced': 9.942334460131238e-05,
#   'blanket': 9.942334460131238e-05,
#   'atm': 0.001292503479817061,
#   'the': 0.030522966792602902,
#   'new': 0.001292503479817061,
#   'years': 9.942334460131238e-05,
#   'dam': 9.942334460131238e-05,
#   'frogs': 9.942334460131238e-05,
#   'calm': 9.942334460131238e-05,
#   "'": 0.0021873135812288725,
#   'trees': 9.942334460131238e-05,
#   'small': 0.0006959634122091867,
#   'customers.': 0.0006959634122091867,
#   'x': 0.0006959634122091867,
#   'prevented': 0.0006959634122091867,
#   'located': 0.001292503479817061,
#   'playfully': 9.942334460131238e-05,
#   'softly': 9.942334460131238e-05,
#   'interest': 0.001292503479817061,
#   'kayakers': 9.942334460131238e-05,
#   '5': 0.000994233446013124,
#   'have': 9.942334460131238e-05,
#   'hikers': 9.942334460131238e-05,
#   'provided': 0.001292503479817061,
#   'am': 0.0006959634122091867,
#   'customers': 0.0006959634122091867,
#   'schedule': 0.0006959634122091867,
#   'overseas': 0.0006959634122091867,
#   'm': 0.012030224696758799,
#   'swimmers': 9.942334460131238e-05,
#   'our': 0.001292503479817061,
#   'meandering': 9.942334460131238e-05,
#   'banks.': 0.0006959634122091867,
#   'balance': 0.001292503479817061,
#   'her': 0.0006959634122091867,
#   'swayed': 9.942334460131238e-05,
#   'apprehended': 0.0006959634122091867,
#   'open': 0.001292503479817061,
#   'stood': 9.942334460131238e-05,
#   'warm': 0.0006959634122091867,
#   'played': 9.942334460131238e-05,
#   'waters': 9.942334460131238e-05,
#   'fishermen': 9.942334460131238e-05,
#   'cash': 0.0006959634122091867,
#   'variety': 9.942334460131238e-05,
#   'on': 0.0006959634122091867,
#   'sandcastle': 9.942334460131238e-05,
#   'city': 0.0006959634122091867,
#   'thief.': 0.0006959634122091867,
#   'against': 9.942334460131238e-05,
#   'water': 9.942334460131238e-05,
#   'smooth': 9.942334460131238e-05,
#   'market': 0.0006959634122091867,
#   'b': 0.016802545237621792,
#   'soared': 0.0006959634122091867,
#   'skipped': 9.942334460131238e-05,
#   'lining': 9.942334460131238e-05,
#   'gear': 9.942334460131238e-05,
#   'were': 9.942334460131238e-05,
#   'level': 9.942334460131238e-05,
#   'shallow': 9.942334460131238e-05,
#   'update': 0.0018890435474249354,
#   'institution)': 0.001292503479817061,
#   'ducks': 9.942334460131238e-05,
#   'dangerously': 9.942334460131238e-05,
#   'competitive': 0.001292503479817061,
#   'rates.': 0.0006959634122091867,
#   'campers': 9.942334460131238e-05,
#   'spot': 9.942334460131238e-05,
#   'online': 0.001292503479817061,
#   'last': 0.0006959634122091867,
#   'services': 0.001292503479817061,
#   '9': 0.000994233446013124,
#   'city.': 0.0006959634122091867,
#   'applied': 0.0006959634122091867,
#   'service.': 0.0006959634122091867,
#   'retirement': 0.0006959634122091867,
#   'paycheck': 0.0006959634122091867,
#   'savings': 0.00248558361503281,
#   'she': 0.0036786637502485586,
#   'make': 0.0006959634122091867,
#   'its': 0.0006959634122091867,
#   'M': 0.0006959634122091867,
#   'between': 0.001292503479817061,
#   'financial': 0.0036786637502485586,
#   'came': 9.942334460131238e-05,
#   'reeds': 9.942334460131238e-05,
#   'center.': 0.0006959634122091867,
#   'rains.': 9.942334460131238e-05,
#   'moonlight': 9.942334460131238e-05,
#   'tents': 9.942334460131238e-05,
#   'j': 9.942334460131238e-05,
#   'D': 9.942334460131238e-05,
#   'collected': 9.942334460131238e-05,
#   'oak': 9.942334460131238e-05,
#   'e': 0.0746669317955856,
#   'is': 0.0006959634122091867,
#   'w': 0.006064824020680056,
#   'r': 0.03231258699542652,
#   'mortgage': 0.001292503479817061,
#   'echoed': 9.942334460131238e-05,
#   'rewards.': 0.0006959634122091867,
#   'tadpoles': 9.942334460131238e-05,
#   'bank': 0.013223304831974548,
#   'my': 0.00666136408828793,
#   'L': 9.942334460131238e-05,
#   'a': 0.06243786040962418,
#   'buy': 0.0006959634122091867,
#   'invested': 0.0006959634122091867,
#   'T': 0.0063630940544839925,
#   'crossed': 9.942334460131238e-05,
#   'R': 9.942334460131238e-05,
#   'along': 9.942334460131238e-05,
#   'into': 0.001292503479817061,
#   'set': 9.942334460131238e-05,
#   'narrow': 9.942334460131238e-05,
#   'businesses.': 0.0006959634122091867,
#   '(financial': 0.001292503479817061,
#   'n': 0.05080532909127063,
#   'works': 0.003082123682640684,
#   'peacefully': 9.942334460131238e-05,
#   'A': 0.0006959634122091867,
#   'house.': 0.0006959634122091867,
#   'natural': 9.942334460131238e-05,
#   'q': 0.000994233446013124,
#   'deer': 9.942334460131238e-05,
#   'swans': 9.942334460131238e-05,
#   'deposit': 0.0018890435474249354,
#   'bank.': 0.009047524358719427,
#   'money': 0.001292503479817061,
#   'officer': 0.0006959634122091867,
#   'f': 0.013223304831974548,
#   'convenience.': 0.0006959634122091867,
#   'branch': 0.0006959634122091867,
#   'old': 9.942334460131238e-05,
#   'eroded': 9.942334460131238e-05,
#   'banking': 0.0018890435474249354,
#   'serene': 9.942334460131238e-05,
#   'tall': 9.942334460131238e-05,
#   'marked': 9.942334460131238e-05,
#   'paddled': 9.942334460131238e-05,
#   'assistance': 0.0006959634122091867,
#   'investment': 0.0006959634122091867,
#   'picnic': 9.942334460131238e-05,
#   'hues.': 9.942334460131238e-05,
#   'traveling.': 0.0006959634122091867,
#   'prey.': 9.942334460131238e-05,
#   'waiting': 9.942334460131238e-05,
#   'I': 0.005170013919268244,
#   'transfer': 0.00248558361503281,
#   'border)': 9.942334460131238e-05,
#   '.': 0.013521574865778485,
#   'gracefully': 9.942334460131238e-05,
#   'deposited': 0.0006959634122091867,
#   'gently': 9.942334460131238e-05,
#   'check': 0.0036786637502485586,
#   'sunset': 9.942334460131238e-05,
#   'guard': 0.0006959634122091867,
#   'waddled': 9.942334460131238e-05,
#   'withdrew': 0.0006959634122091867,
#   'heavy': 9.942334460131238e-05,
#   'rose': 9.942334460131238e-05,
#   'picnics.': 9.942334460131238e-05,
#   'account.': 0.001292503479817061,
#   'of': 0.001292503479817061,
#   'apply': 0.0006959634122091867,
#   'pebbles': 9.942334460131238e-05,
#   'and': 0.0006959634122091867,
#   ')': 0.0006959634122091867,
#   'heron': 9.942334460131238e-05,
#   'district.': 0.0006959634122091867,
#   'onto': 9.942334460131238e-05,
#   'out': 9.942334460131238e-05,
#   'funds': 0.001292503479817061,
#   'profits': 0.0006959634122091867,
#   'stones': 9.942334460131238e-05,
#   'smile.': 0.0006959634122091867,
#   'canoeists': 9.942334460131238e-05,
#   'river.': 9.942334460131238e-05,
#   'through': 0.0006959634122091867,
#   'line': 9.942334460131238e-05,
#   'bend': 9.942334460131238e-05,
#   'o': 0.035295287333465895,
#   'river,': 9.942334460131238e-05,
#   'sun': 9.942334460131238e-05,
#   'swimming': 9.942334460131238e-05,
#   'built': 9.942334460131238e-05,
#   'atmosphere.': 9.942334460131238e-05,
#   'security': 0.001292503479817061,
#   'u': 0.010240604493935176,
#   'S': 0.0018890435474249354,
#   's': 0.0329091270630344,
#   'meeting': 0.0006959634122091867,
#   'wildlife.': 9.942334460131238e-05,
#   'splashed': 9.942334460131238e-05,
#   'before': 0.0006959634122091867,
#   'attractive': 0.0006959634122091867,
#   'system': 0.0006959634122091867,
#   'long-term': 0.0006959634122091867,
#   'stock': 0.0006959634122091867,
#   'teller.': 0.0006959634122091867,
#   'k': 0.01918870550805329,
#   'plants.': 9.942334460131238e-05,
#   'as': 0.003082123682640684,
#   'home.': 0.0006959634122091867,
#   'this': 0.0018890435474249354,
#   'quarter.': 0.0006959634122091867,
#   'account': 0.00248558361503281,
#   'was': 9.942334460131238e-05,
#   'g': 0.007556174189699742,
#   'rowers': 9.942334460131238e-05,
#   'accounts.': 0.0006959634122091867,
#   '(': 0.0006959634122091867,
#   'card.': 0.0006959634122091867,
#   'sandcastles': 9.942334460131238e-05,
#   'corporate': 0.0006959634122091867,
#   'he': 0.0006959634122091867,
#   'home': 9.942334460131238e-05,
#   'greeted': 0.0006959634122091867,
#   'by': 9.942334460131238e-05,
#   'barrier': 9.942334460131238e-05,
#   'excellent': 0.0006959634122091867,
#   'shallows': 9.942334460131238e-05,
#   'to': 0.015609465102406045,
#   'd': 0.017995625372837543,
#   'up': 9.942334460131238e-05,
#   'y': 0.007556174189699742,
#   'sound': 9.942334460131238e-05,
#   'manager': 0.0006959634122091867,
#   'majestically': 9.942334460131238e-05,
#   'offered': 0.0006959634122091867,
#   'offers': 0.0036786637502485586,
#   'aquatic': 9.942334460131238e-05,
#   'at': 0.010240604493935176,
#   'headquarters': 0.001292503479817061,
#   'h': 0.027241996420759595,
#   'teeming': 9.942334460131238e-05,
#   'holding': 9.942334460131238e-05,
#   "hey're": 0.0006959634122091867,
#   'approved': 0.0006959634122091867,
#   'withdrawal': 0.0006959634122091867,
#   'behind': 9.942334460131238e-05,
#   'with': 0.0018890435474249354,
#   'credit': 0.001292503479817061,
#   'rocks': 9.942334460131238e-05,
#   'deposit.': 0.0006959634122091867,
#   'planning': 0.001292503479817061,
#   'check.': 0.0006959634122091867,
#   'are': 0.001292503479817061,
#   'direct': 0.0006959634122091867,
#   'services.': 0.0006959634122091867,
#   'overlooking': 9.942334460131238e-05,
#   'growth.': 0.0006959634122091867,
#   'grassy': 9.942334460131238e-05,
#   'lines': 9.942334460131238e-05,
#   'c': 0.024855836150328096,
#   'leisurely': 9.942334460131238e-05,
#   'river': 9.942334460131238e-05,
#   'stroll': 9.942334460131238e-05,
#   'v': 0.007556174189699742,
#   'rates': 0.0018890435474249354,
#   "sister's": 0.0006959634122091867,
#   'H': 0.00039769337840524953,
#   'l': 0.01083714456154305,
#   'habitat': 9.942334460131238e-05,
#   'information': 0.001292503479817061,
#   'still': 9.942334460131238e-05,
#   'pm.': 0.0006959634122091867,
#   'across': 9.942334460131238e-05,
#   'situated': 9.942334460131238e-05,
#   'enjoyed': 9.942334460131238e-05,
#   'frolicked': 9.942334460131238e-05,
#   'glassy': 9.942334460131238e-05,
#   'provides': 0.0006959634122091867,
#   'winding': 9.942334460131238e-05,
#   'campsite': 9.942334460131238e-05,
#   'muddy': 9.942334460131238e-05,
#   'popular': 9.942334460131238e-05,
#   'willow': 9.942334460131238e-05,
#   'cast': 9.942334460131238e-05,
#   'opportunities': 0.0006959634122091867,
#   'rustled': 9.942334460131238e-05,
#   'his': 9.942334460131238e-05,
#   'exchange': 0.0006959634122091867,
#   'application.': 0.0006959634122091867,
#   'in': 0.00248558361503281,
#   ',': 9.942334460131238e-05,
#   'shaded': 9.942334460131238e-05,
#   'we': 0.0018890435474249354,
#   'turtles.': 9.942334460131238e-05,
#   'B': 9.942334460131238e-05,
#   "bank's": 0.003082123682640684,
#   ' ': 0.12030224696758798,
#   'spread': 9.942334460131238e-05,
#   'checking': 0.001292503479817061,
#   'analyst': 0.0006959634122091867,
#   'they': 0.0006959634122091867,
#   'followed': 9.942334460131238e-05,
#   'beavers': 9.942334460131238e-05,
#   'various': 0.0006959634122091867,
#   't': 0.05468283953072181,
#   'advisor': 0.0006959634122091867,
#   'fisherman': 9.942334460131238e-05,
#   'creating': 9.942334460131238e-05,
#   'downstream': 9.942334460131238e-05,
#   '-': 0.00039769337840524953,
#   'vibrant': 9.942334460131238e-05,
#   'loan': 0.0018890435474249354,
#   'kids': 9.942334460131238e-05,
#   'cool': 9.942334460131238e-05,
#   'glided': 9.942334460131238e-05,
#   'trail': 9.942334460131238e-05,
#   'construction': 0.0006959634122091867,
#   'otters': 9.942334460131238e-05,
#   "let's": 9.942334460131238e-05,
#   'perched': 9.942334460131238e-05,
#   'manager.': 0.0006959634122091867,
#   'rocky': 9.942334460131238e-05,
#   'need': 0.010240604493935176,
#   'children': 9.942334460131238e-05,
#   'robbery.': 0.0006959634122091867,
#   'i': 0.04066414794193677,
#   'tree': 9.942334460131238e-05,
#   'visit': 0.001292503479817061,
#   'near': 9.942334460131238e-05,
#   'close': 9.942334460131238e-05,
#   'their': 9.942334460131238e-05,
#   'sandy': 9.942334460131238e-05,
#   'planner': 0.0006959634122091867,
#   'shimmered': 9.942334460131238e-05,
#   'caught': 9.942334460131238e-05,
#   'rushing': 9.942334460131238e-05,
#   'from': 0.0018890435474249354,
#   'for': 0.0036786637502485586,
#   'slid': 9.942334460131238e-05,
#   'accounts': 0.0006959634122091867,
#   'down': 9.942334460131238e-05,
#   'straight': 9.942334460131238e-05,
#   'customer': 0.0006959634122091867,
#   'F': 0.0006959634122091867},
#  'River Border': {'W': 0.0003210015247572426,
#   'painted': 0.0005617526683251745,
#   'p': 0.007543535831795201,
#   '(river': 0.0015247572425969023,
#   'erosion.': 0.0005617526683251745,
#   'password.': 8.025038118931065e-05,
#   'flooding.': 0.0005617526683251745,
#   'drink': 0.0005617526683251745,
#   'cards': 8.025038118931065e-05,
#   'navigated': 0.0010432549554610384,
#   'raced': 0.0005617526683251745,
#   'blanket': 0.0005617526683251745,
#   'atm': 8.025038118931065e-05,
#   'the': 0.06845357515448199,
#   'new': 8.025038118931065e-05,
#   'years': 0.0005617526683251745,
#   'dam': 0.0005617526683251745,
#   'frogs': 0.0005617526683251745,
#   'calm': 0.0010432549554610384,
#   "'": 0.0003210015247572426,
#   'trees': 0.0015247572425969023,
#   'small': 8.025038118931065e-05,
#   'customers.': 8.025038118931065e-05,
#   'x': 8.025038118931065e-05,
#   'prevented': 8.025038118931065e-05,
#   'located': 8.025038118931065e-05,
#   'playfully': 0.0005617526683251745,
#   'softly': 0.0005617526683251745,
#   'interest': 8.025038118931065e-05,
#   'kayakers': 0.0005617526683251745,
#   '5': 8.025038118931065e-05,
#   'have': 0.0005617526683251745,
#   'hikers': 0.0005617526683251745,
#   'provided': 0.0010432549554610384,
#   'am': 8.025038118931065e-05,
#   'customers': 8.025038118931065e-05,
#   'schedule': 8.025038118931065e-05,
#   'overseas': 8.025038118931065e-05,
#   'm': 0.007302784688227269,
#   'swimmers': 0.0005617526683251745,
#   'our': 8.025038118931065e-05,
#   'meandering': 0.0005617526683251745,
#   'banks.': 8.025038118931065e-05,
#   'balance': 8.025038118931065e-05,
#   'her': 8.025038118931065e-05,
#   'swayed': 0.0005617526683251745,
#   'apprehended': 8.025038118931065e-05,
#   'open': 8.025038118931065e-05,
#   'stood': 0.0005617526683251745,
#   'warm': 8.025038118931065e-05,
#   'played': 0.0005617526683251745,
#   'waters': 0.0010432549554610384,
#   'fishermen': 0.0010432549554610384,
#   'cash': 8.025038118931065e-05,
#   'variety': 0.0005617526683251745,
#   'on': 0.002006259529732766,
#   'sandcastle': 0.0005617526683251745,
#   'city': 8.025038118931065e-05,
#   'thief.': 8.025038118931065e-05,
#   'against': 0.0005617526683251745,
#   'water': 0.0010432549554610384,
#   'smooth': 0.0010432549554610384,
#   'market': 8.025038118931065e-05,
#   'b': 0.01645132814380868,
#   'soared': 8.025038118931065e-05,
#   'skipped': 0.0015247572425969023,
#   'lining': 0.0005617526683251745,
#   'gear': 0.0005617526683251745,
#   'were': 0.0010432549554610384,
#   'level': 0.0005617526683251745,
#   'shallow': 0.0005617526683251745,
#   'update': 8.025038118931065e-05,
#   'institution)': 8.025038118931065e-05,
#   'ducks': 0.0010432549554610384,
#   'dangerously': 0.0005617526683251745,
#   'competitive': 8.025038118931065e-05,
#   'rates.': 8.025038118931065e-05,
#   'campers': 0.0005617526683251745,
#   'spot': 0.0005617526683251745,
#   'online': 8.025038118931065e-05,
#   'last': 8.025038118931065e-05,
#   'services': 8.025038118931065e-05,
#   '9': 8.025038118931065e-05,
#   'city.': 8.025038118931065e-05,
#   'applied': 8.025038118931065e-05,
#   'service.': 8.025038118931065e-05,
#   'retirement': 8.025038118931065e-05,
#   'paycheck': 8.025038118931065e-05,
#   'savings': 8.025038118931065e-05,
#   'she': 8.025038118931065e-05,
#   'make': 8.025038118931065e-05,
#   'its': 0.0005617526683251745,
#   'M': 8.025038118931065e-05,
#   'between': 8.025038118931065e-05,
#   'financial': 8.025038118931065e-05,
#   'came': 0.0005617526683251745,
#   'reeds': 0.0005617526683251745,
#   'center.': 8.025038118931065e-05,
#   'rains.': 0.0005617526683251745,
#   'moonlight': 0.0005617526683251745,
#   'tents': 0.0005617526683251745,
#   'j': 0.0005617526683251745,
#   'D': 0.0003210015247572426,
#   'collected': 0.0005617526683251745,
#   'oak': 0.0005617526683251745,
#   'e': 0.08121338576358238,
#   'is': 8.025038118931065e-05,
#   'w': 0.007302784688227269,
#   'r': 0.048471230238343634,
#   'mortgage': 8.025038118931065e-05,
#   'echoed': 0.0005617526683251745,
#   'rewards.': 8.025038118931065e-05,
#   'tadpoles': 0.0005617526683251745,
#   'bank': 0.022710857876574914,
#   'my': 8.025038118931065e-05,
#   'L': 0.0003210015247572426,
#   'a': 0.04678597223336811,
#   'buy': 8.025038118931065e-05,
#   'invested': 8.025038118931065e-05,
#   'T': 0.010914051841746248,
#   'crossed': 0.0005617526683251745,
#   'R': 0.0008025038118931064,
#   'along': 0.009228793836770725,
#   'into': 8.025038118931065e-05,
#   'set': 0.0015247572425969023,
#   'narrow': 0.0005617526683251745,
#   'businesses.': 8.025038118931065e-05,
#   '(financial': 8.025038118931065e-05,
#   'n': 0.03450766391140358,
#   'works': 8.025038118931065e-05,
#   'peacefully': 0.0005617526683251745,
#   'A': 8.025038118931065e-05,
#   'house.': 8.025038118931065e-05,
#   'natural': 0.0010432549554610384,
#   'q': 0.0003210015247572426,
#   'deer': 0.0005617526683251745,
#   'swans': 0.0005617526683251745,
#   'deposit': 8.025038118931065e-05,
#   'bank.': 0.0005617526683251745,
#   'money': 8.025038118931065e-05,
#   'officer': 8.025038118931065e-05,
#   'f': 0.01645132814380868,
#   'convenience.': 8.025038118931065e-05,
#   'branch': 0.0005617526683251745,
#   'old': 0.0005617526683251745,
#   'eroded': 0.0005617526683251745,
#   'banking': 8.025038118931065e-05,
#   'serene': 0.0005617526683251745,
#   'tall': 0.0005617526683251745,
#   'marked': 0.0005617526683251745,
#   'paddled': 0.0005617526683251745,
#   'assistance': 8.025038118931065e-05,
#   'investment': 8.025038118931065e-05,
#   'picnic': 0.0010432549554610384,
#   'hues.': 0.0005617526683251745,
#   'traveling.': 8.025038118931065e-05,
#   'prey.': 0.0005617526683251745,
#   'waiting': 0.0005617526683251745,
#   'I': 8.025038118931065e-05,
#   'transfer': 8.025038118931065e-05,
#   'border)': 0.0015247572425969023,
#   '.': 0.011636305272450045,
#   'gracefully': 0.0005617526683251745,
#   'deposited': 8.025038118931065e-05,
#   'gently': 0.0005617526683251745,
#   'check': 8.025038118931065e-05,
#   'sunset': 0.0005617526683251745,
#   'guard': 8.025038118931065e-05,
#   'waddled': 0.0005617526683251745,
#   'withdrew': 8.025038118931065e-05,
#   'heavy': 0.0005617526683251745,
#   'rose': 0.0005617526683251745,
#   'picnics.': 0.0005617526683251745,
#   'account.': 8.025038118931065e-05,
#   'of': 0.024155364737982507,
#   'apply': 8.025038118931065e-05,
#   'pebbles': 0.0005617526683251745,
#   'and': 0.0005617526683251745,
#   ')': 0.0008025038118931064,
#   'heron': 0.0010432549554610384,
#   'district.': 8.025038118931065e-05,
#   'onto': 0.0005617526683251745,
#   'out': 0.0005617526683251745,
#   'funds': 8.025038118931065e-05,
#   'profits': 8.025038118931065e-05,
#   'stones': 0.0010432549554610384,
#   'smile.': 8.025038118931065e-05,
#   'canoeists': 0.0010432549554610384,
#   'river.': 0.017895835005216274,
#   'through': 0.0005617526683251745,
#   'line': 0.0005617526683251745,
#   'bend': 0.0005617526683251745,
#   'o': 0.0369151753470829,
#   'river,': 0.0010432549554610384,
#   'sun': 0.0005617526683251745,
#   'swimming': 0.0005617526683251745,
#   'built': 0.0015247572425969023,
#   'atmosphere.': 0.0005617526683251745,
#   'security': 8.025038118931065e-05,
#   'u': 0.007062033544659337,
#   'S': 8.025038118931065e-05,
#   's': 0.028970387609341144,
#   'meeting': 8.025038118931065e-05,
#   'wildlife.': 0.0005617526683251745,
#   'splashed': 0.0005617526683251745,
#   'before': 8.025038118931065e-05,
#   'attractive': 8.025038118931065e-05,
#   'system': 8.025038118931065e-05,
#   'long-term': 8.025038118931065e-05,
#   'stock': 8.025038118931065e-05,
#   'teller.': 8.025038118931065e-05,
#   'k': 0.016210577000240752,
#   'plants.': 0.0005617526683251745,
#   'as': 8.025038118931065e-05,
#   'home.': 8.025038118931065e-05,
#   'this': 8.025038118931065e-05,
#   'quarter.': 8.025038118931065e-05,
#   'account': 8.025038118931065e-05,
#   'was': 0.002969264104004494,
#   'g': 0.011154802985314181,
#   'rowers': 0.0005617526683251745,
#   'accounts.': 8.025038118931065e-05,
#   '(': 0.0008025038118931064,
#   'card.': 8.025038118931065e-05,
#   'sandcastles': 0.0005617526683251745,
#   'corporate': 8.025038118931065e-05,
#   'he': 8.025038118931065e-05,
#   'home': 0.0005617526683251745,
#   'greeted': 8.025038118931065e-05,
#   'by': 0.003450766391140358,
#   'barrier': 0.0005617526683251745,
#   'excellent': 8.025038118931065e-05,
#   'shallows': 0.0005617526683251745,
#   'to': 0.0015247572425969023,
#   'd': 0.018618088435920072,
#   'up': 0.0010432549554610384,
#   'y': 0.007543535831795201,
#   'sound': 0.0005617526683251745,
#   'manager': 8.025038118931065e-05,
#   'majestically': 0.0005617526683251745,
#   'offered': 8.025038118931065e-05,
#   'offers': 8.025038118931065e-05,
#   'aquatic': 0.0005617526683251745,
#   'at': 0.0005617526683251745,
#   'headquarters': 8.025038118931065e-05,
#   'h': 0.043896958510552926,
#   'teeming': 0.0005617526683251745,
#   'holding': 0.0005617526683251745,
#   "hey're": 8.025038118931065e-05,
#   'approved': 8.025038118931065e-05,
#   'withdrawal': 8.025038118931065e-05,
#   'behind': 0.0005617526683251745,
#   'with': 0.0005617526683251745,
#   'credit': 8.025038118931065e-05,
#   'rocks': 0.0010432549554610384,
#   'deposit.': 8.025038118931065e-05,
#   'planning': 8.025038118931065e-05,
#   'check.': 8.025038118931065e-05,
#   'are': 8.025038118931065e-05,
#   'direct': 8.025038118931065e-05,
#   'services.': 8.025038118931065e-05,
#   'overlooking': 0.0005617526683251745,
#   'growth.': 8.025038118931065e-05,
#   'grassy': 0.0010432549554610384,
#   'lines': 0.0005617526683251745,
#   'c': 0.011395554128882112,
#   'leisurely': 0.0005617526683251745,
#   'river': 0.004413770965412085,
#   'stroll': 0.0005617526683251745,
#   'v': 0.015006821282401092,
#   'rates': 8.025038118931065e-05,
#   "sister's": 8.025038118931065e-05,
#   'H': 8.025038118931065e-05,
#   'l': 0.022710857876574914,
#   'habitat': 0.0005617526683251745,
#   'information': 8.025038118931065e-05,
#   'still': 0.0005617526683251745,
#   'pm.': 8.025038118931065e-05,
#   'across': 0.0015247572425969023,
#   'situated': 0.0005617526683251745,
#   'enjoyed': 0.0005617526683251745,
#   'frolicked': 0.0005617526683251745,
#   'glassy': 0.0005617526683251745,
#   'provides': 8.025038118931065e-05,
#   'winding': 0.0005617526683251745,
#   'campsite': 0.0005617526683251745,
#   'muddy': 0.0010432549554610384,
#   'popular': 0.0005617526683251745,
#   'willow': 0.0005617526683251745,
#   'cast': 0.0010432549554610384,
#   'opportunities': 8.025038118931065e-05,
#   'rustled': 0.0005617526683251745,
#   'his': 0.0005617526683251745,
#   'exchange': 8.025038118931065e-05,
#   'application.': 8.025038118931065e-05,
#   'in': 0.0015247572425969023,
#   ',': 0.0005617526683251745,
#   'shaded': 0.0005617526683251745,
#   'we': 0.0005617526683251745,
#   'turtles.': 0.0005617526683251745,
#   'B': 0.0008025038118931064,
#   "bank's": 8.025038118931065e-05,
#   ' ': 0.1259930984672177,
#   'spread': 0.0005617526683251745,
#   'checking': 8.025038118931065e-05,
#   'analyst': 8.025038118931065e-05,
#   'they': 8.025038118931065e-05,
#   'followed': 0.0005617526683251745,
#   'beavers': 0.0005617526683251745,
#   'various': 8.025038118931065e-05,
#   't': 0.04365620736698499,
#   'advisor': 8.025038118931065e-05,
#   'fisherman': 0.0005617526683251745,
#   'creating': 0.0005617526683251745,
#   'downstream': 0.0005617526683251745,
#   '-': 8.025038118931065e-05,
#   'vibrant': 0.0005617526683251745,
#   'loan': 8.025038118931065e-05,
#   'kids': 0.0010432549554610384,
#   'cool': 0.0005617526683251745,
#   'glided': 0.0005617526683251745,
#   'trail': 0.0005617526683251745,
#   'construction': 8.025038118931065e-05,
#   'otters': 0.0015247572425969023,
#   "let's": 0.0005617526683251745,
#   'perched': 0.0005617526683251745,
#   'manager.': 8.025038118931065e-05,
#   'rocky': 0.0005617526683251745,
#   'need': 8.025038118931065e-05,
#   'children': 0.002969264104004494,
#   'robbery.': 8.025038118931065e-05,
#   'i': 0.03210015247572426,
#   'tree': 0.0005617526683251745,
#   'visit': 8.025038118931065e-05,
#   'near': 0.0010432549554610384,
#   'close': 0.0005617526683251745,
#   'their': 0.0010432549554610384,
#   'sandy': 0.0005617526683251745,
#   'planner': 8.025038118931065e-05,
#   'shimmered': 0.0005617526683251745,
#   'caught': 0.0005617526683251745,
#   'rushing': 0.0005617526683251745,
#   'from': 0.0015247572425969023,
#   'for': 0.0015247572425969023,
#   'slid': 0.0005617526683251745,
#   'accounts': 8.025038118931065e-05,
#   'down': 0.0005617526683251745,
#   'straight': 0.0005617526683251745,
#   'customer': 8.025038118931065e-05,
#   'F': 8.025038118931065e-05}}

# %%
def classify_sense(sentence):
  words=sentence.lower().split()
  scores={}
  for sense in prior_probabilities:
    score=math.log(prior_probabilities[sense])
    for word in words:
      if word in conditional_probabilities[sense]:
        score += math.log(conditional_probabilities[sense][word])
      else:
        score+=1/(sum(word_counts[sense].values())+vocab_size)

    scores[sense]=score
  return max(scores,key=scores.get)

# %%
test_sentences=test_df['Sentences for Training ']

# %%
result={}
for sentence in test_sentences:
  result[sentence]=classify_sense(sentence)

for x,y in result.items():
  test_df['Sense of the word "Bank"']=y

test_df
# Out:
#      Unnamed: 0                            Sentences for Training   \
# 94          NaN  The children built a dam on the bank of the ri...
# 95          NaN  We need to withdraw some cash from the bank fo...
# 96          NaN  I need to update my contact information with t...
# 97          NaN  The bank provides online banking services for ...
# 98          NaN  The beavers constructed a dam along the bank o...
# 99          NaN  I need to check my transaction history at the ...
# 100         NaN  She works as a financial consultant at the bank.
#
#     Sense of the word "Bank"
# 94     Financial Institution
# 95     Financial Institution
# 96     Financial Institution
# 97     Financial Institution
# 98     Financial Institution
# 99     Financial Institution
# 100    Financial Institution

# %%
test_sentences = [
    "The children built a dam on the bank of the river using rocks and sticks.",
    "We need to withdraw some cash from the bank for groceries.",
    "I need to update my contact information with the bank.",
    "The bank provides online banking services for convenience.",
    "The beavers constructed a dam along the bank of the river.",
    "I need to check my transaction history at the bank.",
    "she works as a financial consultant at the bank."
]

results={}
for sentence in test_sentences:
    results[sentence]=classify_sense(sentence)
print(f"Sentence\t\t\t\t\t\t\t\t\t\tClassified")
for sentence, result in results.items():
    print(f"{sentence}\t\t{result}\n")
# Out:
# Sentence										Classified
# The children built a dam on the bank of the river using rocks and sticks.		River Border
#
# We need to withdraw some cash from the bank for groceries.		Financial Institution
#
# I need to update my contact information with the bank.		Financial Institution
#
# The bank provides online banking services for convenience.		Financial Institution
#
# The beavers constructed a dam along the bank of the river.		River Border
#
# I need to check my transaction history at the bank.		Financial Institution
#
# she works as a financial consultant at the bank.		Financial Institution
